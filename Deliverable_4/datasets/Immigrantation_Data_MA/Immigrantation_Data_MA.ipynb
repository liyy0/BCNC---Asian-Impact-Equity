# %%
# Visualize "MA Immigration Data.csv"
'''

The term "foreign born" refers to people residing in the United States at the
time of the population survey who were not U.S. citizens at birth. The foreign-born
population includes naturalized U.S. citizens, lawful permanent immigrants (or green-card holders),
refugees and asylees, certain legal nonimmigrants (including those on student, work,
or some other temporary visas), and persons residing in the country without authorization.


The term "U.S. born" refers to people residing in the United States who were U.S. citizens in one
of three categories: people born in one of the 50 states or the District of Columbia; people born in U.S.
Insular Areas such as Puerto Rico or Guam; or people who were born abroad to at least one U.S. citizen parent.
'''
# Out:
# '\n\nThe term "foreign born" refers to people residing in the United States at the\ntime of the population survey who were not U.S. citizens at birth. The foreign-born\npopulation includes naturalized U.S. citizens, lawful permanent immigrants (or green-card holders),\nrefugees and asylees, certain legal nonimmigrants (including those on student, work,\nor some other temporary visas), and persons residing in the country without authorization.\n\n\nThe term "U.S. born" refers to people residing in the United States who were U.S. citizens in one\nof three categories: people born in one of the 50 states or the District of Columbia; people born in U.S.\nInsular Areas such as Puerto Rico or Guam; or people who were born abroad to at least one U.S. citizen parent.\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("MA Immigration Data.csv")
#print(df.head())


def maDecadeData(year):
    labels = df.loc[2:7]["Unnamed: 0"].tolist()
    size = df.loc[2:7][year].tolist()
    for i in range(len(size)):
        size[i] = int(size[i].replace(',', ''))
        labels[i] = labels[i].replace('Born in ', '')

    txt = 'Region of Birth ' + year + ' (Excluding born at sea)'
        

    explode = (0, 0.1, 0, 0, 0, 0)

    fig1, ax1 = plt.subplots()

    ax1.pie(size, explode=explode, labels=labels, autopct='%1.1f%%',
            shadow=True)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.legend( labels,
            title ="Born Locations",
            loc ="best",
            bbox_to_anchor =(1, 0, 0.5, 1))

    plt.title(txt)
    plt.show()

    #2020

    #bar chart

    #2019
    name = labels
    price = size
    price,name = zip(*sorted(zip(price,name),reverse = True))
    
    
    # Figure Size
    fig, ax = plt.subplots(figsize =(16, 9))
    
    # Horizontal Bar Plot
    color = []
    for i in range(len(name)):
            if name[i] == 'Asia':
                    color += ['red']
            else:
                    color += ['gray']
        
    ax.barh(name, price, color = color)
    
    # Remove axes splines
    for s in ['top', 'bottom', 'left', 'right']:
        ax.spines[s].set_visible(False)
    
    # Remove x, y Ticks
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    
    # Add padding between axes and labels
    ax.xaxis.set_tick_params(pad = 5)
    ax.yaxis.set_tick_params(pad = 10)
    
    # Add x, y gridlines
    ax.grid(b = True, color ='grey',
            linestyle ='-.', linewidth = 0.5,
            alpha = 0.2)
    
    # Show top values
    ax.invert_yaxis()
    
    # Add annotation to bars
    for i in ax.patches:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,
                str(round((i.get_width()), 2)),
                fontsize = 10, fontweight ='bold',
                color ='grey')
    
    # Add Plot Title
    
    ax.set_title(txt,
                loc ='left', )
    
    # Add Text watermark
    fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
            color ='grey', ha ='right', va ='bottom',
            alpha = 0.7)
    plt.xlabel("Population")
    plt.ylabel("Region")
    
    # Show Plot
    plt.show()


#2019
maDecadeData("2019")
maDecadeData("2000")
maDecadeData("1990")

# %%
labels = ['2019', '2000', '1990']

size = [int(df.loc[3]["2019"].replace(',', '')), int(df.loc[3]["2000"].replace(',', '')), int(df.loc[3]["1990"].replace(',', ''))]
plt.bar(labels, size)
plt.title("Asian Immigrant Change Over Decade")
plt.xlabel("Years")
plt.ylabel("Population")
plt.show()

# %%
#Asian Immigrant Races


labels = df.loc[28:47]["Unnamed: 0"].tolist()
size = df.loc[28:47]['2019'].tolist()
for i in range(len(size)):
        size[i] = int(size[i].replace(',', ''))



fig1, ax1 = plt.subplots(figsize=(15, 10))

ax1.pie(size, labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.legend( labels,
        title ="Born Locations",
        loc ="best",
        bbox_to_anchor =(1, 0, 0.5, 1))

plt.title("Asian Immigrant Races 2019")
plt.show()

#2019
name = labels
price = size
price,name = zip(*sorted(zip(price,name),reverse = True))
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(name, price)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
        ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,
                str(round((i.get_width()), 2)),
                fontsize = 10, fontweight ='bold',
                color ='grey')

# Add Plot Title
ax.set_title('Region of Birth 2019 (Excluding born at sea)',
                loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
        color ='grey', ha ='right', va ='bottom',
        alpha = 0.7)
plt.xlabel("Population")
plt.ylabel("Races")

# Show Plot
plt.show()

# %%
df = pd.read_csv("MA Immigration Data2.csv")
df.head()
labels = df.loc[8:14]["Unnamed: 0"].tolist()
size = df.loc[8:14]['2019'].tolist()

for i in range(len(size)):  
    size[i] = float(size[i].replace('%', ''))

fig1, ax1 = plt.subplots(figsize=(15, 10))

ax1.pie(size, labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.legend( labels,
        title ="Born Locations",
        loc ="best",
        bbox_to_anchor =(1, 0, 0.5, 1))

plt.title("Foreign Born Born 2019")
plt.show()

labels = df.loc[8:14]["Unnamed: 0"].tolist()
size = df.loc[8:14]['Unnamed: 2'].tolist()

for i in range(len(size)):  
    size[i] = float(size[i].replace('%', ''))

fig1, ax1 = plt.subplots(figsize=(15, 10))

ax1.pie(size, labels=labels, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.legend( labels,
        title ="U.S. Born Locations",
        loc ="best",
        bbox_to_anchor =(1, 0, 0.5, 1))

plt.title("U.S. 2019")
plt.show()

# %%
df =  pd.read_csv("Median Household Income.csv")
MAIncome = []
BostonIncome = []
USIncome = []
for i in range(len(df)):
    if(df['Geography'][i] == 'Massachusetts'):
        MAIncome += [df['Household Income by Race'][i]]
    if(df['Geography'][i] == 'Boston'):
        BostonIncome += [df['Household Income by Race'][i]]
    if(df['Geography'][i] == 'United States'):
        USIncome += [df['Household Income by Race'][i]]

print(MAIncome)
df.head()
# Out:
# [85843, 79835, 77385, 75297, 70628, 69160, 66768]
#    ID Year  Year  Household Income by Race  Household Income by Race Moe  \
# 0     2019  2019                     65712                         118.0
# 1     2019  2019                     85843                         991.0
# 2     2019  2019                     77558                        3968.0
# 3     2019  2019                     79018                        4250.0
# 4     2019  2019                     94430                        1212.0
#
#                         Geography    ID Geography  \
# 0                   United States         01000US
# 1                   Massachusetts       04000US25
# 2              Suffolk County, MA    05000US25025
# 3                      Boston, MA  16000US2507000
# 4  Boston-Cambridge-Newton, MA-NH    31000US14460
#
#                   Slug Geography
# 0                  united-states
# 1                  massachusetts
# 2              suffolk-county-ma
# 3                      boston-ma
# ...
